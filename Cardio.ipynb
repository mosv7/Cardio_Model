# %%
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('cardio_train.csv',sep = ';')
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df= df.drop('id' , axis = 'columns')
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df['age'] = np.round(df['age'] / 365)
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0       2     168    62.0    110     80            1     1      0     0
# 1  55.0       1     156    85.0    140     90            3     1      0     0
# 2  52.0       1     165    64.0    130     70            3     1      0     0
# 3  48.0       2     169    82.0    150    100            1     1      0     0
# 4  48.0       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0       2     168    62.0    110     80            1     1      0     0
# 1  55.0       1     156    85.0    140     90            3     1      0     0
# 2  52.0       1     165    64.0    130     70            3     1      0     0
# 3  48.0       2     169    82.0    150    100            1     1      0     0
# 4  48.0       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df['gender'].replace([1,2],value = ['Female','Male'],inplace = True)
df.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8972\2251511958.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace([1,2],value = ['Female','Male'],inplace = True)
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0    Male     168    62.0    110     80            1     1      0     0
# 1  55.0  Female     156    85.0    140     90            3     1      0     0
# 2  52.0  Female     165    64.0    130     70            3     1      0     0
# ...

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0  50.0    Male     168    62.0    110     80            1     1      0     0
# 1  55.0  Female     156    85.0    140     90            3     1      0     0
# 2  52.0  Female     165    64.0    130     70            3     1      0     0
# 3  48.0    Male     169    82.0    150    100            1     1      0     0
# 4  48.0  Female     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df[['smoke','alco','active','cardio']] = df[['smoke','alco','active','cardio']].replace([0,1],value = ['no','yes'])
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc smoke alco  \
# 0  50.0    Male     168    62.0    110     80            1     1    no   no
# 1  55.0  Female     156    85.0    140     90            3     1    no   no
# 2  52.0  Female     165    64.0    130     70            3     1    no   no
# 3  48.0    Male     169    82.0    150    100            1     1    no   no
# 4  48.0  Female     156    56.0    100     60            1     1    no   no
#
#   active cardio
# 0    yes     no
# 1    yes    yes
# 2     no    yes
# 3    yes    yes
# 4     no     no

# %%
df[['cholesterol','gluc']] = df[['cholesterol','gluc']].replace({1: 'normal', 2: 'above normal', 3: 'well above normal'})
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo        cholesterol    gluc  \
# 0  50.0    Male     168    62.0    110     80             normal  normal
# 1  55.0  Female     156    85.0    140     90  well above normal  normal
# 2  52.0  Female     165    64.0    130     70  well above normal  normal
# 3  48.0    Male     169    82.0    150    100             normal  normal
# 4  48.0  Female     156    56.0    100     60             normal  normal
#
#   smoke alco active cardio
# 0    no   no    yes     no
# 1    no   no    yes    yes
# 2    no   no     no    yes
# 3    no   no    yes    yes
# 4    no   no     no     no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  float64
#  1   gender       70000 non-null  object
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  object
#  7   gluc         70000 non-null  object
#  8   smoke        70000 non-null  object
#  9   alco         70000 non-null  object
#  10  active       70000 non-null  object
#  11  cardio       70000 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 6.4+ MB

# %%
df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3816)

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo        cholesterol    gluc  \
# 0  50.0    Male     168    62.0    110     80             normal  normal
# 1  55.0  Female     156    85.0    140     90  well above normal  normal
# 2  52.0  Female     165    64.0    130     70  well above normal  normal
# 3  48.0    Male     169    82.0    150    100             normal  normal
# 4  48.0  Female     156    56.0    100     60             normal  normal
#
#   smoke alco active cardio
# 0    no   no    yes     no
# 1    no   no    yes    yes
# 2    no   no     no    yes
# 3    no   no    yes    yes
# 4    no   no     no     no

# %%
sns.boxplot(data = df , x = 'age')
# Out:
# <Axes: xlabel='age'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['height'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['ap_hi'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['ap_lo'])
plt.show()

# %%
df.drop(df[(df['ap_hi'] > 240)|(df['ap_hi'] <40) | (df['ap_lo'] >240) |  (df['ap_lo'] < 40)].index, inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['ap_hi'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['ap_lo'])
plt.show()

# %%
df['BMI'] = df['weight'] / (df['height']/100)**2
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo        cholesterol    gluc  \
# 0  50.0    Male     168    62.0    110     80             normal  normal
# 1  55.0  Female     156    85.0    140     90  well above normal  normal
# 2  52.0  Female     165    64.0    130     70  well above normal  normal
# 3  48.0    Male     169    82.0    150    100             normal  normal
# 4  48.0  Female     156    56.0    100     60             normal  normal
#
#   smoke alco active cardio        BMI
# 0    no   no    yes     no  21.967120
# 1    no   no    yes    yes  34.927679
# 2    no   no     no    yes  23.507805
# 3    no   no    yes    yes  28.710479
# 4    no   no     no     no  23.011177

# %%
conditions = [
    ((df['ap_hi'] < 90) | (df['ap_lo'] < 60)),  # Low blood pressure
    ((df['ap_hi'] >= 90) & (df['ap_hi'] < 120) & (df['ap_lo'] >= 60) & (df['ap_lo'] < 80)),  # Normal
    (((df['ap_hi'] >= 120) & (df['ap_hi'] < 140)) | ((df['ap_lo'] >= 80) & (df['ap_lo'] < 90))),  # Lightly high
    ((df['ap_hi'] >= 140) | (df['ap_lo'] >= 90))  # High
]

# Define the corresponding choices
choices = ['low', 'normal', 'lightly high', 'high']

# Use np.select() to create the new column, with a default value for unmatched rows
df['blood_pressure'] = np.select(conditions, choices, default='unknown')

# Display the first few rows of the DataFrame
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo        cholesterol    gluc  \
# 0  50.0    Male     168    62.0    110     80             normal  normal
# 1  55.0  Female     156    85.0    140     90  well above normal  normal
# 2  52.0  Female     165    64.0    130     70  well above normal  normal
# 3  48.0    Male     169    82.0    150    100             normal  normal
# 4  48.0  Female     156    56.0    100     60             normal  normal
#
#   smoke alco active cardio        BMI blood_pressure
# 0    no   no    yes     no  21.967120   lightly high
# 1    no   no    yes    yes  34.927679           high
# 2    no   no     no    yes  23.507805   lightly high
# 3    no   no    yes    yes  28.710479           high
# 4    no   no     no     no  23.011177         normal

# %%
df['blood_pressure'].value_counts()
# Out:
# blood_pressure
# lightly high    43965
# high            15161
# normal           9417
# low               232
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder

le = LabelEncoder()

# %%
cols = ['cholesterol', 'gluc', 'smoke', 'alco', 'active','cardio', 'gender']
for col in cols:
    df[col+'_enc'] = le.fit_transform(df[col])

df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo        cholesterol    gluc  \
# 0  50.0    Male     168    62.0    110     80             normal  normal
# 1  55.0  Female     156    85.0    140     90  well above normal  normal
# 2  52.0  Female     165    64.0    130     70  well above normal  normal
# 3  48.0    Male     169    82.0    150    100             normal  normal
# 4  48.0  Female     156    56.0    100     60             normal  normal
#
#   smoke alco  ... cardio        BMI  blood_pressure cholesterol_enc  gluc_enc  \
# 0    no   no  ...     no  21.967120    lightly high               1         1
# 1    no   no  ...    yes  34.927679            high               2         1
# 2    no   no  ...    yes  23.507805    lightly high               2         1
# 3    no   no  ...    yes  28.710479            high               1         1
# 4    no   no  ...     no  23.011177          normal               1         1
#
# ...

# %%
bb = df.groupby(['blood_pressure' , 'cardio'])[['cardio_enc']].count().reset_index().rename(columns={'cardio_enc':'count'})
bb
# Out:
#   blood_pressure cardio  count
# 0           high     no   2580
# 1           high    yes  12581
# 2   lightly high     no  24675
# 3   lightly high    yes  19290
# 4            low     no    153
# 5            low    yes     79
# 6         normal     no   7330
# 7         normal    yes   2087

# %%
X = df[['age', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol_enc', 'gluc_enc', 'smoke_enc', 'alco_enc', 'active_enc'] ]
y = df['cardio_enc']

# %%
X.head()
# Out:
#     age  height  weight  ap_hi  ap_lo  cholesterol_enc  gluc_enc  smoke_enc  \
# 0  50.0     168    62.0    110     80                1         1          0
# 1  55.0     156    85.0    140     90                2         1          0
# 2  52.0     165    64.0    130     70                2         1          0
# 3  48.0     169    82.0    150    100                1         1          0
# 4  48.0     156    56.0    100     60                1         1          0
#
#    alco_enc  active_enc
# 0         0           1
# 1         0           1
# 2         0           0
# 3         0           1
# 4         0           0

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: cardio_enc, dtype: int64

# %%
X_train , X_test, y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , precision_score, recall_score, f1_score , roc_auc_score, confusion_matrix

# %%
Cls = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=5, min_samples_split=4, min_samples_leaf=2, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None, monotonic_cst=None)
Cls.fit(X_train, y_train)

y_pred = Cls.predict(X_test)
print("Accuracy:", Cls.score(X_test, y_test))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy: 0.7300981461286805
# Precision: 0.7690582959641256
# Recall: 0.6616033755274262
# F1 Score: 0.7112954442356296
# ROC AUC Score: 0.7304485030115514

# %%
cn = confusion_matrix(y_test, y_pred)
cn
# Out:
# array([[6563, 1648],
#        [2807, 5488]])

# %%
sns.heatmap(cn , annot=True)
# Out:
# <Axes: >

# %%
features = [ 'age'	,'height'	,'weight,'	'ap_hi',	'ap_lo',	'cholesterol',	'gluc',	'smoke',	'alco',	'active'
]

# %%
import pickle
model_diabates = "diabetes_model.pkl"
pickle.dump(Cls, open(model_diabates , "wb"))
